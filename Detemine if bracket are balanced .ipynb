# %% [markdown]
# - this this ;esson we are going to determine whether or ot a set of bracket are balanced or ot by makingg use the stack data structure that we defien inthe previous sheet
# ![2022-03-31%2022.03.49%20www.educative.io%205f4bce7e00ef.png](attachment:2022-03-31%2022.03.49%20www.educative.io%205f4bce7e00ef.png)

# %% [markdown]
# ###### as above our alggorithms is as follows
# ---
# - we iterate through the character of the string
# - if we get opeing bracket, push it onto the stack
# - if we ecounter a closing bracket pop  off an element from the stack and match it with the closing bracket if it is an opeing bracket and of the same type as the closing bracket we conclude it is a successful match  and move on , if its ot we ll coonclude that the set of brackets is ot balanced
# - the stack will be empty at the end of iteration for balanced example of brackets while we ll be left with some elements i the stack for an unbalanced example
